# %% [markdown]
# # Introduction

# %%
# %ls
# Out:
# cradar/
# DataWorkshop.ipynb
# DataWorkshop (maximilian-ThinkPad-X1-Carbon-4th's conflicted copy 2017-09-03).ipynb
# doku/
# Kasse
# led-scripts/
# lightsd/
# lightsd-vis/
# MatplotLib_Tut.ipynb
# myplot1.png
# node_modules/
# political_twitter_archive-master/
# political_twitter_archive-master.zip
# voctomix/

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(2, 11)
y = x **2
y
# Out:
# array([  4,   9,  16,  25,  36,  49,  64,  81, 100])

# %%
plt.plot(x, y)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('My Nice Plot $\pi$')
plt.grid(True)
plt.savefig('myplot1.png', dpi=300)

# %%
ls
# Out:
# cradar/
# DataWorkshop.ipynb
# DataWorkshop (maximilian-ThinkPad-X1-Carbon-4th's conflicted copy 2017-09-03).ipynb
# doku/
# Kasse
# led-scripts/
# lightsd/
# lightsd-vis/
# MatplotLib_Tut.ipynb
# myplot1.png
# node_modules/
# political_twitter_archive-master/
# political_twitter_archive-master.zip
# voctomix/

# %%
plt.figure()
plt.plot(x, y, label = 'measured')
plt.plot(x, y+20, label='calculated')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('My Nice Plot $\pi$')
plt.grid(True)
plt.legend()

# %%
plt.figure()
plt.plot(x, y, label = 'measured')
plt.plot(x, y+20, label='calculated')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('My Nice Plot $\pi$')
plt.grid(True)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# %matplotlib inline

# %%
plt.figure()
plt.plot(x, y, 'r--o', label = 'measured')
plt.plot(x, y+20, label='calculated', color=(0.5, 0.5, 1))
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('My Nice Plot $\pi$')
plt.grid(True)
plt.legend()

# %%
plt.figure()
lines1 = plt.plot(x, y, 'r--o', label = 'measured')
plt.plot(x, y+20, label='calculated', color=(0.5, 0.5, 1))
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('My Nice Plot $\pi$')
plt.grid(True)
plt.legend()

# %%
p = lines1[0]

# %%
line1, line2 = plt.plot(x,y,x,y+20)

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
plt.figure()
lines1 = plt.plot(x, y, 'r--o', label = 'measured')
p = lines1[0]
plt.plot(x, y+20, label='calculated', color=(0.5, 0.5, 1))
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('My Nice Plot $\pi$')
plt.grid(True)
plt.legend()
plt.setp(lines1, marker='+') #setproperty
p.set_color('darkgreen')

# %%
plt.setp?

# %%
# check out p.set_<tab>
# checkout gallery on matplotlib website

# %%
x2 = np.linspace(0, 2 * np.pi, 500)
y1 = np.sin(x2)
y2 = np.sin(3 * x2)

fig, ax = plt.subplots()
ax.fill(x2, y1, 'b', x2, y2, 'r', alpha=0.24234234)
plt.show()

# %%
plt.figure()
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# ## Text

# %%
plt.figure()
plt.plot(x,y)
plt.text(5, 60, 'hello') #this will move with plot in interactive mode
plt.figtext(0.2, 0.6, 'figure text') # this will stay in place inside graph
plt.figtext(1.2, 0.6, 'figure text') # this will be displayed outside the graph

# %%
plt.figure()
plt.plot(x,y)
plt.text(5, 60, 'hello $\pi$') #this will move with plot in interactive modeb
plt.figtext(0.2, 0.6, 'figure text') # this will stay in place inside graph
ax = plt.gca()
ax.annotate('Important', xy=(6,35), xytext=(8,30), arrowprops={'facecolor': 'r'})

# %%
über = 4
über*2
# Out:
# 8

# %% [markdown]
# ## Subplots

# %%
sub1 = plt.subplot(2,3,1)
sub3 = plt.subplot(233)
sub6 = plt.subplot(2,3,6)
sub1.plot(x, y)
plt.tight_layout()

# %%
rows = 5
cols = 3
n = 0

for row in range(1, rows + 1):
    for col in range(1, cols +1):
        n += 1
        sub = plt.subplot(rows, cols, n)
        sub.plot(x,y * n)

# %%
rows = 5
cols = 3

def plot_many(rows, cols, plot = 'plot'):
    """Plot rows times cols plots in a grid.
    
    ...
    """
    n = 0
    for row in range(1, rows + 1):
        for col in range(1, cols +1):
            n += 1
            sub = plt.subplot(rows, cols, n)
            getattr(sub, plot)(x, y * n)
            sub.plot(x,y * n)
plot_many(rows=5, cols=2, plot ='semilogy')

# %% [markdown]
# ## Animation
